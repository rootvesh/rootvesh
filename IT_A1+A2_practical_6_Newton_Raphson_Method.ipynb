# %% [markdown]
# <a href="https://colab.research.google.com/github/rootvesh/rootvesh/blob/main/IT_A1%2BA2_practical_6_Newton_Raphson_Method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ex-1-Using Newton-Raphson Method find the root of the eqn x^3-5*x-9=0 correct upto 4 decimal places 
#Defining Function
def f(x):
    return x**3 - 5*x - 9

# Defining derivative of function
def g(x):
    return 3*x**2 - 5

# Implementing Newton Raphson Method

def newtonRaphson(x0,e,N):
    print('\n\n*** NEWTON RAPHSON METHOD IMPLEMENTATION ***')
    step = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Divide by zero error!')
            break
        
        x1 = x0 - f(x0)/g(x0)
        print('Iteration-%d, x1 = %0.4f and f(x1) = %0.4f' % (step, x1, f(x1)))
        x0 = x1
        step = step + 1
        
        if step > N:
            flag = 0
            break
        
        condition = abs(f(x1)) > e
    
    if flag==1:
        print('\nRequired root is: %0.5f' % x1)
    else:
        print('\nNot Convergent.')


# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
newtonRaphson(x0,e,N)
# Out:
# Enter Guess: 2
# Tolerable Error: 0.00001
# Maximum Step: 8
#
#
# *** NEWTON RAPHSON METHOD IMPLEMENTATION ***
# Iteration-1, x1 = 3.5714 and f(x1) = 18.6968
# Iteration-2, x1 = 3.0094 and f(x1) = 3.2071
# Iteration-3, x1 = 2.8647 and f(x1) = 0.1859
# Iteration-4, x1 = 2.8552 and f(x1) = 0.0008
# Iteration-5, x1 = 2.8552 and f(x1) = 0.0000
#
# Required root is: 2.85520

# %%
# Ex-2-Using Newton-Raphson Method find the root of the eqn x-cos(x)=0 correct upto 5 decimal places 
#Defining Function
import math
def f(x):
    return x-math.cos(x)

# Defining derivative of function
def g(x):
    return 1+math.sin(x)

# Implementing Newton Raphson Method

def newtonRaphson(x0,e,N):
    print('\n\n*** NEWTON RAPHSON METHOD IMPLEMENTATION ***')
    step = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Divide by zero error!')
            break
        
        x1 = x0 - f(x0)/g(x0)
        print('Iteration-%d, x1 = %0.4f and f(x1) = %0.4f' % (step, x1, f(x1)))
        x0 = x1
        step = step + 1
        
        if step > N:
            flag = 0
            break
        
        condition = abs(f(x1)) > e
    
    if flag==1:
        print('\nRequired root is: %0.5f' % x1)
    else:
        print('\nNot Convergent.')


# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
newtonRaphson(x0,e,N)
# Out:
# Enter Guess: 0
# Tolerable Error: 0.000001
# Maximum Step: 7
#
#
# *** NEWTON RAPHSON METHOD IMPLEMENTATION ***
# Iteration-1, x1 = 1.0000 and f(x1) = 0.4597
# Iteration-2, x1 = 0.7504 and f(x1) = 0.0189
# Iteration-3, x1 = 0.7391 and f(x1) = 0.0000
# Iteration-4, x1 = 0.7391 and f(x1) = 0.0000
#
# Required root is: 0.73909

# %%
#Ex-3  Using Newton-Raphson Method find the root of the eqn x^3+x-1=0 correct upto 4 decimal places 
#Defining Function
def f(x):
    return x**3 +x - 1

# Defining derivative of function
def g(x):
    return 3*x**2 +1

# Implementing Newton Raphson Method

def newtonRaphson(x0,e,N):
    print('\n\n*** NEWTON RAPHSON METHOD IMPLEMENTATION ***')
    step = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Divide by zero error!')
            break
        
        x1 = x0 - f(x0)/g(x0)
        print('Iteration-%d, x1 = %0.4f and f(x1) = %0.4f' % (step, x1, f(x1)))
        x0 = x1
        step = step + 1
        
        if step > N:
            flag = 0
            break
        
        condition = abs(f(x1)) > e
    
    if flag==1:
        print('\nRequired root is: %0.5f' % x1)
    else:
        print('\nNot Convergent.')


# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
newtonRaphson(x0,e,N)
# Out:
# Enter Guess: 0
# Tolerable Error: 0.00001
# Maximum Step: 7
#
#
# *** NEWTON RAPHSON METHOD IMPLEMENTATION ***
# Iteration-1, x1 = 1.0000 and f(x1) = 1.0000
# Iteration-2, x1 = 0.7500 and f(x1) = 0.1719
# Iteration-3, x1 = 0.6860 and f(x1) = 0.0089
# Iteration-4, x1 = 0.6823 and f(x1) = 0.0000
# Iteration-5, x1 = 0.6823 and f(x1) = 0.0000
#
# Required root is: 0.68233

# %%
#Ex-4  Using Newton-Raphson Method find the negative root of the eqn x^4-x^3-10x+7=0 correct upto 4 decimal places
#Defining Function
def f(x):
    return x**4 -x**3-10*x +7

# Defining derivative of function
def g(x):
    return 4*x**3 -3*x**2-10

# Implementing Newton Raphson Method

def newtonRaphson(x0,e,N):
    print('\n\n*** NEWTON RAPHSON METHOD IMPLEMENTATION ***')
    step = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Divide by zero error!')
            break
        
        x1 = x0 - f(x0)/g(x0)
        print('Iteration-%d, x1 = %0.6f and f(x1) = %0.6f' % (step, x1, f(x1)))
        x0 = x1
        step = step + 1
        
        if step > N:
            flag = 0
            break
        
        condition = abs(f(x1)) > e
    
    if flag==1:
        print('\nRequired root is: %0.5f' % x1)
    else:
        print('\nNot Convergent.')


# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
newtonRaphson(x0,e,N)
# Out:
# Enter Guess: -5
# Tolerable Error: 0.00001
# Maximum Step: 10
#
#
# *** NEWTON RAPHSON METHOD IMPLEMENTATION ***
# Iteration-1, x1 = -3.620513 and f(x1) = 262.485848
# Iteration-2, x1 = -2.522965 and f(x1) = 88.806951
# Iteration-3, x1 = -1.571472 and f(x1) = 32.694072
# Iteration-4, x1 = -0.578689 and f(x1) = 13.092833
# Iteration-5, x1 = 0.532774 and f(x1) = 1.601603
# Iteration-6, x1 = 0.689079 and f(x1) = 0.007476
# Iteration-7, x1 = 0.689818 and f(x1) = 0.000000
#
# Required root is: 0.68982

# %%
#Ex-5  Using Newton-Raphson Method find the root of the eqn x^3-x^2+2=0 correct upto 4 decimal places 
#Defining Function
def f(x):
    return x**3 -x**2 +2

# Defining derivative of function
def g(x):
    return 3*x**2 -2*x

# Implementing Newton Raphson Method

def newtonRaphson(x0,e,N):
    print('\n\n*** NEWTON RAPHSON METHOD IMPLEMENTATION ***')
    step = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Divide by zero error!')
            break
        
        x1 = x0 - f(x0)/g(x0)
        print('Iteration-%d, x1 = %0.4f and f(x1) = %0.4f' % (step, x1, f(x1)))
        x0 = x1
        step = step + 1
        
        if step > N:
            flag = 0
            break
        
        condition = abs(f(x1)) > e
    
    if flag==1:
        print('\nRequired root is: %0.5f' % x1)
    else:
        print('\nNot Convergent.')


# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
newtonRaphson(x0,e,N)
# Out:
# Enter Guess: -2
# Tolerable Error: 0.00001
# Maximum Step: 7
#
#
# *** NEWTON RAPHSON METHOD IMPLEMENTATION ***
# Iteration-1, x1 = -1.3750 and f(x1) = -2.4902
# Iteration-2, x1 = -1.0793 and f(x1) = -0.4222
# Iteration-3, x1 = -1.0046 and f(x1) = -0.0232
# Iteration-4, x1 = -1.0000 and f(x1) = -0.0001
# Iteration-5, x1 = -1.0000 and f(x1) = -0.0000
#
# Required root is: -1.00000

# %%
#Ex-6  Using Newton-Raphson Method find the root of the eqn x^2-4x-10=0 correct upto 4 decimal places 
#Defining Function
def f(x):
    return x**2 -4*x - 10

# Defining derivative of function
def g(x):
    return 2*x -4

# Implementing Newton Raphson Method

def newtonRaphson(x0,e,N):
    print('\n\n*** NEWTON RAPHSON METHOD IMPLEMENTATION ***')
    step = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Divide by zero error!')
            break
        
        x1 = x0 - f(x0)/g(x0)
        print('Iteration-%d, x1 = %0.4f and f(x1) = %0.4f' % (step, x1, f(x1)))
        x0 = x1
        step = step + 1
        
        if step > N:
            flag = 0
            break
        
        condition = abs(f(x1)) > e
    
    if flag==1:
        print('\nRequired root is: %0.5f' % x1)
    else:
        print('\nNot Convergent.')


# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
newtonRaphson(x0,e,N)
# Out:
# Enter Guess: 5
# Tolerable Error: 0.00001
# Maximum Step: 7
#
#
# *** NEWTON RAPHSON METHOD IMPLEMENTATION ***
# Iteration-1, x1 = 5.8333 and f(x1) = 0.6944
# Iteration-2, x1 = 5.7428 and f(x1) = 0.0082
# Iteration-3, x1 = 5.7417 and f(x1) = 0.0000
#
# Required root is: 5.74166
